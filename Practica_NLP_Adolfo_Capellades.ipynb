# %% [markdown]
# # 1 - Descarga y exploración del corpus (EDA)
#
# El alumno descargará el/los corpus que desee (detalle sobre los datos a utilizar en
# el siguiente punto) y realizará un análisis exploratorio de los datos.
# Este ejercicio deberá contener:
#
# - Cardinalidad del vocabulario
# - Distribución de reviews por número de estrellas
# - No de reviews positivas y negativas
# - N-grams más frecuentes
# - Nubes de palabras
# - Visualización en 2 dimensiones de algunos word embeddings calculados con
# Word2Vec (elegir 4-5 palabras y pintar las top 10 más similares)
# - Conclusiones de la exploración
# - Cualquier otra métrica / exploración / cálculo que el alumno considere
#
# ## Datasets
# Reviews de Amazon: Reviews de productos de Amazon clasificadas por categorías (libros,
# electrónica, automoción, ...). Las reviews contienen la calificación (número de estrellas) por
# lo que es perfecto para problemas de clasificación supervisada del sentimiento.
# El alumno deberá escoger el dataset que desee (puede trabajar con varios si así lo
# prefiere) de los que aparecen en la columna “5-core”. Se recomienda trabajar con
# subsets de dichos datasets para evitar problemas de memoria.
# Enlace: https://cseweb.ucsd.edu/~jmcauley/datasets/amazon/links.html

# %% [markdown]
# El dataset elegido es _Musical Instruments_ con las siguientes características:
#
#     reviewerID - ID of the reviewer, e.g. A2SUAM1J3GNN3B
#     asin - ID of the product, e.g. 0000013714
#     reviewerName - name of the reviewer
#     helpful - helpfulness rating of the review, e.g. 2/3
#     reviewText - text of the review
#     overall - rating of the product
#     summary - summary of the review
#     unixReviewTime - time of the review (unix time)
#     reviewTime - time of the review (raw)

# %%
#Cargamos el dataset
import pandas as pd
import gzip
import urllib.request

df_link = 'https://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Musical_Instruments_5.json.gz'
gzFile = 'reviews_Musical_Instruments_5.json.gz'


def download_df(link, toFile):
  urllib.request.urlretrieve(link, toFile)

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')


#--------------------------
download_df(df_link, gzFile)
df = getDF('./' + gzFile )
df.to_csv('df_file.csv')

# %%
# función para mostrar texto en negrita
def bold(text):
    return f"\033[1m{text}\033[0m"

# %%
df.head(5)
# Out:
#        reviewerID        asin  \
# 0  A2IBPI20UZIR0U  1384719342
# 1  A14VAT5EAX3D9S  1384719342
# 2  A195EZSQDW3E21  1384719342
# 3  A2C00NNG1ZQQG2  1384719342
# 4   A94QU4C90B1AX  1384719342
#
#                                        reviewerName   helpful  \
# 0  cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                              Jake  [13, 14]
# 2                     Rick Bennette "Rick Bennette"    [1, 1]
# 3                         RustyBill "Sunday Rocker"    [0, 0]
# 4                                     SEAN MASLANKA    [0, 0]
#
#                                           reviewText  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
#                                  summary  unixReviewTime   reviewTime
# 0                                   good      1393545600  02 28, 2014
# 1                                   Jake      1363392000  03 16, 2013
# 2                   It Does The Job Well      1377648000  08 28, 2013
# 3          GOOD WINDSCREEN FOR THE MONEY      1392336000  02 14, 2014
# 4  No more pops when I record my vocals.      1392940800  02 21, 2014

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10261 entries, 0 to 10260
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      10261 non-null  object
#  1   asin            10261 non-null  object
#  2   reviewerName    10234 non-null  object
#  3   helpful         10261 non-null  object
#  4   reviewText      10261 non-null  object
#  5   overall         10261 non-null  float64
#  6   summary         10261 non-null  object
#  7   unixReviewTime  10261 non-null  int64
#  8   reviewTime      10261 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.0+ MB

# %% [markdown]
# El dataset no contiene nulos en los campos interesados: reviewText, overall

# %%
df.shape
# Out:
# (10261, 9)

# %%
#longitud máxima reseña (review)
import numpy as np
import re

rec_max = np.max(df['reviewText'].str.len().argmax())

num_words = 0
list_of_words_rw = []
x_re = ''

for x in df['reviewText'].tolist():
  matches = re.findall('[a-zA-Z0-9 ]*', x)

  len_x = len(matches)

  list_of_words_rw.append(len_x) # list with size of every line
  num_words = max(num_words, len_x) # max num of words per line


# Calculate the median number of words in each line.
median_words_rw = np.median(list_of_words_rw)


corpus = ''
total_words = 0

for x in df['reviewText'].tolist():
  matches = re.findall('[a-zA-Z0-9 ]*', x)
  corpus += ''.join(matches)
  total_words += len(x.split())

# %%
print(bold('Max record length          :')+ ' {:>6}'.format(rec_max))
print(bold('Max length words review    :')+ ' {:>6}'.format(num_words))
print(bold('Mean length words review   :')+' {:>6.2f}'.format(median_words_rw))
print(bold('Palabras totales reviewText:'), total_words)
# Out:
# Max record length          :   6576
# Max length words review    :    817
# Mean length words review   :  17.00
# Palabras totales reviewText: 925371

# %% [markdown]
# En esta sección obtengo los totales por score (overall) que me servirá para contrastar con el análisis de sentimiento.

# %%
ovrall = ovrall = df.groupby('overall')['overall'].count()

print(ovrall.index.values)
print(ovrall.array)
# Out:
# [1. 2. 3. 4. 5.]
# <NumpyExtensionArray>
# [np.int64(217), np.int64(250), np.int64(772), np.int64(2084), np.int64(6938)]
# Length: 5, dtype: int64

# %%
# Distribución de reviews por número de estrellas
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
x = ovrall.index.values
y = ovrall.array

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(autoscale_on=True,
       xlim=(0,5), xticks=np.arange(1, 7),
       ylim=(0, 8000), yticks=np.arange(0, 8000, 1000))

ax.set_xlabel('Scoring')
ax.set_ylabel('# Reviews')
ax.set_title('Overall Rating')

plt.show()

# %%
from collections import Counter

# %%
words_nltk = corpus.lower().split()

# %%
words_nltk[:10]
# Out:
# ['not', 'much', 'to', 'write', 'about', 'here', 'but', 'it', 'does', 'exactly']

# %%
wf = Counter(words_nltk)
wf_most_common = wf.most_common(10)
wf_most_common
# Out:
# [('the', 43540),
#  ('a', 27752),
#  ('and', 26862),
#  ('i', 23732),
#  ('to', 22967),
#  ('it', 19799),
#  ('is', 14554),
#  ('of', 13579),
#  ('for', 12984),
#  ('this', 11223)]

# %%
# N-gramas
from nltk import ngrams
from nltk.probability import FreqDist

# %%
bigrams_ = list(ngrams(words_nltk, 2))
trigrams_ = list(ngrams(words_nltk, 3))

# %%
bigrams_[:10]
# Out:
# [('not', 'much'),
#  ('much', 'to'),
#  ('to', 'write'),
#  ('write', 'about'),
#  ('about', 'here'),
#  ('here', 'but'),
#  ('but', 'it'),
#  ('it', 'does'),
#  ('does', 'exactly'),
#  ('exactly', 'what')]

# %%
trigrams_[:10]
# Out:
# [('not', 'much', 'to'),
#  ('much', 'to', 'write'),
#  ('to', 'write', 'about'),
#  ('write', 'about', 'here'),
#  ('about', 'here', 'but'),
#  ('here', 'but', 'it'),
#  ('but', 'it', 'does'),
#  ('it', 'does', 'exactly'),
#  ('does', 'exactly', 'what'),
#  ('exactly', 'what', 'its')]

# %%
# Wordcloud
from wordcloud import WordCloud
def plot_word_cloud(corpus):
    wordcloud = WordCloud(max_font_size=50, max_words=50, background_color="white").generate(' '.join(corpus))
    plt.figure(figsize=(12,6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
words_list = corpus.lower().strip().split()
plot_word_cloud(words_list)

# %% [markdown]
# # 2 - Preprocesamiento

# %%
# Dependencias
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
import numpy as np
import random
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# NLP Preprocessing pipeline
class nlp_pipeline:
  '''
  nlp_pipeline realiza el preprocesado del corpus
  antes del entrenamiento.
  Parámetros:
  -----------
  -> Array de strings
  <- Array de string preprocesados

  Tratamiento:
  ------------
  - minúsculas
  - eliminar caracteres
  - tokenizar
  - quitar stop words
  - pad sequence (tamaño medio reviews)
  '''
  def __init__(self, corpus):
    self.corpus = corpus
    self.stop_words_list = set(stopwords.words('english'))

  def preprocessing(self):
      prep_corpus = self.corpus.copy()
      for pos, line in enumerate(prep_corpus):
        line = self.to_lower(line)
        line = self.leave_nonword_chars(line)
        prep_corpus[pos] = self.leave_stop_words(line)

      return np.array(self.pad_sequence(prep_corpus))

  def to_lower(self, param:str):
    '''
    Get a parameter string
    Return the same content but in lowercase
    '''

    return param.lower()

  def leave_nonword_chars(self, param:str):
    '''
    Get a parameter string
    Return the non alphanumeric characters
    '''
    return re.sub('[^a-zA-Z0-9 ]', '', param)

  def leave_stop_words(self, param:str):
    '''
    Get a parameter string
    Return the non stopword words
    '''
    return " ".join([word for word in param.split() if word not in self.stop_words_list])

  def pad_sequence(self, param: list):
    '''
    Get a parameter list
    Return a new list with pad sequence as a result
    of the mean length of the list text lines
    '''

    # Give a list with the size of each line
    list_of_words = [len(line.split())  for line in param]

    # Calculate the median number of words in the list of lines
    median_words = np.median(list_of_words)

    int_median_words = int(np.round(median_words, 0))

    # Truncate all the lines to the median length of words
    trunc_list = []
    for line in param:
      temp_low=line.split() #temp list of words by line

      trunc_list.append(" ".join(temp_low[:int_median_words]))

    # Returns truncated list with the default pad_sequence
    return trunc_list

# %%
#pd.set_option('display.max_colwidth', None)
df[['reviewText', 'overall']][:5]
# Out:
#                                           reviewText  overall
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0

# %%
# Añadimos una columna para la clasificación binaria
'''
Criterio binario para análisis de sentimiento
Overall: 0-5
Distribución:
Overall     Sentimiento (1-positivo, 0-negativo)
-------     -----------
0-3           0
4-5           1
'''

df['bin_label'] = df.apply(lambda row: 1 if row['overall'] >= 4 else 0, axis=1)

# %%
nlp_pipe_inst = nlp_pipeline(df['reviewText'])
preproc_corpus = nlp_pipe_inst.preprocessing()
preproc_corpus[:5]
# Out:
# array(['much write exactly supposed filters pop sounds recordings much crisp one lowest prices pop filters amazon might well buy honestly work despite pricing',
#        'product exactly quite affordablei realized double screened arrived even better expectedas added bonus one screens carries small hint smell old grape candy used buy reminiscents sake cannot',
#        'primary job device block breath would otherwise produce popping sound allowing voice pass noticeable reduction volume high frequencies double cloth filter blocks pops lets voice coloration metal',
#        'nice windscreen protects mxl mic prevents pops thing gooseneck marginally able hold screen position requires careful positioning clamp avoid sagging',
#        'pop filter great looks performs like studio filter youre recording vocals eliminate pops gets recorded sing'],
#       dtype='<U372')

# %%
# save dataset

# %%
# BoW - CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer='word', ngram_range=(1, 1))
X2 = vectorizer.fit_transform(preproc_corpus)
X2.sum(axis=0)
total_counts = X2.sum(axis=0).tolist()[0]
words = vectorizer.get_feature_names_out()

# %%
# Number of times a word appears
word_counts = dict(zip(words, total_counts))
print(word_counts)
# Out:
# {'000': 2, '0012053': 1, '0022uf': 2, '0028': 1, '009': 3, '009042': 1, '01': 1, '010': 4, '010s': 1, '011': 5, '012': 2, '012dlx': 1, '012s': 2, '013': 2, '0135013': 1, '013s': 1, '016': 1, '016ny': 2, '02': 1, '025026': 1, '028': 1, '0313': 1, '032': 1, '034036': 1, '038': 1, '042': 1, '046mm': 1, '048': 1, '05': 4, '053': 1, '05mm': 1, '060mm': 3, '07': 4, '0733150406': 1, '08': 2, '0818': 1, '088mm': 1, '09': 2, '0942': 1, '099': 1, '0990502000': 1, '09s': 1, '0db': 1, '10': 153, '100': 95, '1000': 7, '1000500': 1, '1000s': 1, '100low': 1, '100mm': 2, '100pound': 1, '100s': 2, '100th': 1, '100w': 2, '100watt': 1, '101': 1, '1012': 1, '1015': 2, '1020': 1, '103': 1, '1032': 1, '1046': 5, '1046s': 1, '1047s': 1, '1052': 1, '1099': 1, '10a125': 1, '10db': 1, '10feet': 1, '10foot': 2, '10footers': 1, '10ft': 2, '10i': 1, '10k': 1, '10lol': 1, '10m': 1, '10mm': 3, '10pack': 1, '10s': 18, '10th': 1, '10w': 1, '10watts': 1, '10x': 2, '10xs': 1, '11': 18, '110': 3, '1100': 1, '110v': 1, '111': 1, '112': 2, '1134': 2, '114': 4, '1148': 1, '114mm': 3, '114s': 1, '114si': 1, '115': 1, '1152': 2, '1152s': 1, '1156': 1, '116': 3, '1164': 1, '116th': 1, '118221paper': 1, '11850': 1, '119': 2, '11hole': 2, '11s': 6, '11th': 1, '12': 130, '120': 7, '1200': 2, '1202': 4, '1202fx': 3, '120i': 1, '1213': 1, '1215': 1, '122311': 1, '1234': 7, '1249': 1, '125': 3, '1254': 1, '1254s': 1, '1262013': 1, '126mm': 1, '12at7': 3, '12au7': 1, '12ax7': 10, '12ft': 1, '12inch': 1, '12or': 1, '12pack': 2, '12s': 2, '12string': 16, '12strings': 1, '12sttring': 1, '12th': 4, '12u': 1, '12v': 1, '12vac': 2, '12vdc': 1, '13': 28, '130': 3, '1300': 1, '1334': 1, '1362s': 1, '13inch': 2, '13rd': 1, '13th': 1, '14': 52, '140': 1, '1400': 2, '1434': 13, '149': 1, '1499': 2, '14in': 1, '14inch': 2, '14w': 1, '15': 65, '150': 10, '1500': 2, '15000': 1, '150ls': 1, '150s': 1, '1520': 1, '1532nd': 1, '1534': 4, '1540': 1, '1561': 1, '15delivered': 1, '15foot': 1, '15s': 2, '15the': 1, '15watt': 1, '16': 10, '160': 1, '1617': 1, '1634': 4, '1699': 1, '16gb': 1, '16s': 1, '16th': 1, '16u': 1, '17': 6, '170': 1, '1700ma': 2, '17500': 1, '179': 1, '17900': 1, '17amps': 1, '17ma': 1, '18': 12, '180': 2, '1800s': 1, '180watts': 1, '181': 1, '182113': 1, '183': 1, '1834': 5, '1861': 1, '18th': 2, '18v': 2, '18vd': 1, '18vdc': 1, '18watt': 1, '190lbs': 1, '1918': 1, '1934': 1, '1940s': 2, '1948': 1, '1950s': 1, '1953': 1, '1957': 1, '1960s': 3, '1962': 2, '1963': 1, '1966': 3, '1967': 2, '1968': 3, '1969': 2, '1970': 2, '1970s': 3, '1971ive': 1, '1972': 1, '1973': 3, '1974': 1, '1976': 1, '1978': 1, '1979': 2, '1980': 3, '1980s': 5, '1981more': 1, '1985': 1, '1989': 1, '199': 1, '1990ish': 1, '1990s': 2, '1991': 1, '1993': 2, '1994': 2, '1996': 1, '1997': 1, '1999': 1, '1asx2sjtxk': 1, '1frd125': 1, '1high': 1, '1mm': 3, '1o': 1, '1preset': 1, '1s': 1, '1st': 22, '1star': 1, '1u': 2, '1x12': 4, '1x8': 2, '20': 103, '200': 17, '2000': 8, '2000for': 1, '2000ish': 1, '2000ma': 1, '2000s': 1, '200300': 1, '200300nice': 1, '2004': 2, '2005': 2, '2006': 1, '2007': 2, '2008': 2, '2009': 2, '200w': 1, '2010': 5, '2011': 6, '2012': 4, '2012the': 1, '2013': 3, '20130924star': 1, '201314': 1, '2013i': 1, '2014': 6, '2020': 4, '2020s': 1, '2025': 2, '202and': 1, '2030': 1, '2032': 2, '2036': 1, '2050': 1, '205k': 1, '20db': 2, '20foot': 1, '20mm': 3, '20s': 1, '20w': 1, '20x': 1, '20yrs': 1, '21': 7, '210': 3, '212': 2, '21234': 1, '212r': 1, '212rline': 1, '214ce': 1, '21calls': 1, '21each': 1, '21ft': 1, '22': 6, '220': 6, '22014': 1, '2203': 1, '2203kk': 1, '220sce': 1, '220v': 1, '222': 1, '2223': 1, '223k': 1, '225': 1, '22db': 1, '23': 11, '230': 1, '230lb': 1, '234': 2, '235': 1, '24': 11, '240v': 1, '240vhappy': 1, '245': 3, '247534': 1, '2488ive': 1, '24ghz': 1, '24hrs': 1, '25': 57, '250': 3, '2500': 3, '250ma': 1, '250s': 1, '2524neutrik': 1, '2534': 2, '25ft': 3, '25i': 1, '25r': 4, '25what': 1, '26': 1, '2626': 1, '26scale': 1, '27': 3, '2734': 1, '275': 1, '28': 2, '280' ...

# %% [markdown]
# ## Features

# %%
from sklearn.model_selection import train_test_split

# %%
# creo mi columna de referencia
ground_truth = df['bin_label']

# %%
x_train, x_test, y_train, y_test = train_test_split(
    preproc_corpus,
    ground_truth,
    train_size=0.75,
    test_size=0.25,
    random_state=42,
    shuffle=True,
    stratify=ground_truth
)

# %%
# Extracción características TF-IDF
tfidf = TfidfVectorizer(
    max_df=0.95,
    min_df=5,
    max_features=2500,
    strip_accents='ascii',
    ngram_range=(1, 1)
)
tfidf.fit(x_train)
# Out:
# TfidfVectorizer(max_df=0.95, max_features=2500, min_df=5, strip_accents='ascii')

# %%
print(list(tfidf.vocabulary_.items())[:20])
# Out:
# [('good', np.int64(904)), ('dont', np.int64(615)), ('see', np.int64(1864)), ('better', np.int64(232)), ('basic', np.int64(201)), ('strings', np.int64(2096)), ('price', np.int64(1646)), ('range', np.int64(1711)), ('work', np.int64(2456)), ('well', np.int64(2416)), ('length', np.int64(1172)), ('somewhat', np.int64(2003)), ('appears', np.int64(142)), ('level', np.int64(1180)), ('hosa', np.int64(1016)), ('cable', np.int64(307)), ('quality', np.int64(1700)), ('place', np.int64(1571)), ('products', np.int64(1663)), ('sound', np.int64(2014))]

# %%
x_train_ = tfidf.transform(x_train)
x_test_ = tfidf.transform(x_test)

# %%
# Some review words (TF-IDF)
i = random.randint(0, len(x_train))


doc_vector = x_train_[i]
df_tfidf = pd.DataFrame(doc_vector.T.todense(), index=tfidf.get_feature_names_out(), columns=['tfidf'])
df_tfidf = df_tfidf[df_tfidf['tfidf'] > 0]

top_n = 10

# %%
print(bold('ID        :')+' {}'.format(i))
print(bold('Sentiment :')+' {}'.format(y_train[i]))
print(bold('Review    :')+' {} \n'.format(x_train[i]))

print('Top {} words with highest TF_IDF in the review {}:\n{}'.format(top_n, i, df_tfidf.sort_values(by=["tfidf"],ascending=False)[:top_n]))
print('\nTop {} words with lowest TF_IDF in the review {}:\n{}'.format(top_n, i, df_tfidf.sort_values(by=["tfidf"],ascending=False)[-top_n:]))
# Out:
# ID        : 3610
# Sentiment : 0
# Review    : youre always dropping picks losing picks breaking picks perfect fits 58 guitar picks stickies onto guitar wherever seems enough stickyness move around times still ti grip like
#
# Top 10 words with highest TF_IDF in the review 3610:
#              tfidf
# picks     0.553086
# dropping  0.275362
# losing    0.266567
# 58        0.261697
# breaking  0.248462
# onto      0.218713
# move      0.211714
# grip      0.196353
# times     0.190086
# youre     0.179595
#
# Top 10 words with lowest TF_IDF in the review 3610:
#             tfidf
# youre    0.179595
# guitar   0.177031
# fits     0.171843
# seems    0.163860
# always   0.157708
# still    0.155910
# around   0.154316
# enough   0.153369
# perfect  0.151880
# like     0.100464

# %% [markdown]
# # 3 - Modelo de ML

# %% [markdown]
# ## Train & Test

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import time

# %%
xgb_model = XGBClassifier(n_estimators=750, learning_rate=0.05)


ts_start = int(time.time())
xgb_model.fit(x_train_, y_train, verbose=True)
ts_end = int(time.time())
xgb_train_time = ts_end - ts_start
print(bold('Time:'), xgb_train_time)
# Out:
# Time: 46

# %% [markdown]
# ## Métricas y Conclusiones (ML)

# %%
from sklearn.metrics import accuracy_score
from matplotlib import pyplot

# %%
# evaluate predictions
y_pred_xgb = xgb_model.predict(x_test_)
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
print(bold('Accuracy:')+' %.2f%%' % (xgb_accuracy * 100.0))
# Out:
# Accuracy: 88.07%

# %%
# Get feature names and their importance
feature_names = tfidf.get_feature_names_out()
importance = xgb_model.feature_importances_

# Pair them and sort
feature_importance = list(zip(feature_names, importance))
feature_importance_sorted = sorted(feature_importance, key=lambda x: x[1], reverse=True)

# top 10
top_10 = feature_importance_sorted[:10]
for feature, score in top_10:
    print(f"{feature}: {score:.4f}")
# Out:
# ok: 0.0102
# easy: 0.0079
# wasnt: 0.0053
# cut: 0.0051
# great: 0.0048
# return: 0.0048
# unfortunately: 0.0047
# actually: 0.0046
# defective: 0.0046
# broke: 0.0046

# %%
# Métricas
def metricas_xgb():
  length_xgb = len(y_pred_xgb)
  count_0_xgb = 0
  count_1_xgb = 0
  for j in range(len(y_pred_xgb)):
    if y_pred_xgb[j] == 0:
      count_0_xgb += 1
    else:
      count_1_xgb += 1

def mostrar_metricas_xgb():
  metricas_xgb
  print(bold('Prediction xgb'))
  print(' xgb accuracy: {:>4.2f}'.format(xgb_accuracy*100))
  print('        0 xgb: {:>4}'.format(count_0_xgb), '({:>6.2f}%)'.format(count_0_xgb/length_xgb * 100))
  print('        1 xgb: {:>4}'.format(count_1_xgb), '({:>6.2f}%)'.format(count_1_xgb/length_xgb * 100))

# %%
mostrar_metricas_xgb()
# Out:
# Prediction xgb
#  xgb accuracy: 88.07
#         0 xgb:   42 (  1.64%)
#         1 xgb: 2524 ( 98.36%)

# %% [markdown]
# # 4 - Modelo de DL

# %% [markdown]
# ## Train & Test

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
vocabulary_size = len(tfidf.vocabulary_)

# %%
# Create a Keras Sequential model
ff_model = Sequential([
  Dense(128, activation='elu'),                      # second hidden layer with 32 neuron
  Dense(64, activation='elu'),                      # second hidden layer with 32 neuron
  Dense(32, activation='elu'),                       # third hidden layer with 8 neuron
  Dense(1, activation='sigmoid')            #output layer
])
ff_model.compile(optimizer='adam', loss='binary_crossentropy')

# %%
ff_model.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_22 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
time_ff_ini = time.time()

hist = ff_model.fit(
    x_train_,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(x_train_, y_train),
    verbose=2
)
ff_train_time = time.time() - time_ff_ini
# Out:
# Epoch 1/20
# 241/241 - 4s - 17ms/step - loss: 0.3486 - val_loss: 0.2238
# Epoch 2/20
# 241/241 - 2s - 9ms/step - loss: 0.2401 - val_loss: 0.1843
# Epoch 3/20
# 241/241 - 2s - 9ms/step - loss: 0.1960 - val_loss: 0.1476
# Epoch 4/20
# 241/241 - 3s - 14ms/step - loss: 0.1723 - val_loss: 0.1200
# Epoch 5/20
# 241/241 - 2s - 9ms/step - loss: 0.1511 - val_loss: 0.1076
# Epoch 6/20
# 241/241 - 2s - 9ms/step - loss: 0.1278 - val_loss: 0.0819
# Epoch 7/20
# 241/241 - 2s - 9ms/step - loss: 0.1017 - val_loss: 0.0663
# Epoch 8/20
# 241/241 - 2s - 9ms/step - loss: 0.0747 - val_loss: 0.0478
# Epoch 9/20
# 241/241 - 3s - 12ms/step - loss: 0.0577 - val_loss: 0.0417
# Epoch 10/20
# 241/241 - 3s - 12ms/step - loss: 0.0484 - val_loss: 0.0396
# Epoch 11/20
# 241/241 - 4s - 18ms/step - loss: 0.0315 - val_loss: 0.0214
# Epoch 12/20
# 241/241 - 2s - 9ms/step - loss: 0.0231 - val_loss: 0.0143
# Epoch 13/20
# 241/241 - 2s - 9ms/step - loss: 0.0177 - val_loss: 0.0068
# Epoch 14/20
# 241/241 - 3s - 14ms/step - loss: 0.0180 - val_loss: 0.0082
# Epoch 15/20
# 241/241 - 4s - 16ms/step - loss: 0.0193 - val_loss: 0.0158
# Epoch 16/20
# 241/241 - 3s - 11ms/step - loss: 0.0158 - val_loss: 0.0060
# Epoch 17/20
# 241/241 - 2s - 9ms/step - loss: 0.0081 - val_loss: 0.0028
# Epoch 18/20
# 241/241 - 3s - 12ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 19/20
# 241/241 - 3s - 12ms/step - loss: 0.0012 - val_loss: 5.9479e-04
# Epoch 20/20
# 241/241 - 2s - 9ms/step - loss: 5.7115e-04 - val_loss: 0.0010

# %%
print(bold('Train time:'), ff_train_time)
# Out:
# Train time: 54.92994832992554

# %%
# Prediction
y_pred_ff = ff_model.predict(x_test_)
y_pred_class = (y_pred_ff > 0.5).astype(int)  # Convert to 0 or 1
# Out:
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Calculate accuracy

ff_accuracy = accuracy_score(y_test, y_pred_class)
print(bold('Test Accuracy:')+' {:4.2f}%'.format(ff_accuracy*100))
# Out:
# Test Accuracy: 83.87%

# %% [markdown]
# ## Métricas y Conclusiones (DL)

# %%
def metricas_ff():
  # Initializing array of integers
  y_pred_ffi = np.empty_like(y_pred_xgb)

  for i in range(len(y_pred_ff)):
    y_pred_ffi[i] = int(np.round(y_pred_ff[i][0]))


def mostrar_metricas_ff():
  metricas_ff()
  # Printing predictions
  print(bold('Prediction ffi'))
  print('  ff accuracy: {:>4.2f}'.format(ff_accuracy*100))
  print('  0 ff : {:>4}'.format(count_0_ff), '({:>6.2f}%)'.format(count_0_ff/length_ff * 100))
  print('  1 ff : {:>4}'.format(count_1_ff), '({:>6.2f}%)'.format(count_1_ff/length_ff * 100))
  print('\n')

#  length_ff = len(y_pred_ff)
#  count_0_ff = 0
#  count_1_ff = 0
#  for j in range(len(y_pred_ffi)):
#    if y_pred_ffi[j] == 0:
#      count_0_ff += 1
#    else:
#      count_1_ff += 1


#length_xgb = len(y_pred_xgb)
#count_0_xgb = 0
#count_1_xgb = 0
#for j in range(len(y_pred_xgb)):
#  if y_pred_xgb[j] == 0:
#    count_0_xgb += 1
#  else:
#    count_1_xgb += 1

# %%
#  print(bold('Prediction ffi'))
#  print('  ff accuracy: {:>4.2f}'.format(ff_accuracy*100))
#  print('  0 ff : {:>4}'.format(count_0_ff), '({:>6.2f}%)'.format(count_0_ff/length_ff * 100))
#  print('  1 ff : {:>4}'.format(count_1_ff), '({:>6.2f}%)'.format(count_1_ff/length_ff * 100))
#  print('\n')
#
#  print(bold('Prediction xgb'))
#  print(' xgb accuracy: {:>4.2f}'.format(xgb_accuracy*100))
#  print('        0 xgb: {:>4}'.format(count_0_xgb), '({:>6.2f}%)'.format(count_0_xgb/length_xgb * 100))
#  print('        1 xgb: {:>4}'.format(count_1_xgb), '({:>6.2f}%)'.format(count_1_xgb/length_xgb * 100))

# %%
mostrar_metricas_ff()
# Out:
# Prediction ffi
#   ff accuracy: 83.87
#   0 ff :  342 ( 13.33%)
#   1 ff : 2224 ( 86.67%)

# %%
import random
for i in range(5):
  j = random.randint(0, len(y_pred_ff)-1)
  print ('random index: ' + bold(str(j)))
  print('>',x_test[j][:150],'<')
  print('   ff  score: ', y_pred_ffi[j])
  print('   xgb score: ', y_pred_xgb[j])
# Out:
# random index: 2120
# > probably read problem usb connection generating high pitch sound recording making usb functionality unusable amazon reviewer referred fatal flaw heart <
#    ff  score:  1
#    xgb score:  1
# random index: 1033
# > cable works perfect defects cystal clear sound constructed well use studio noticiable problems know road worthy studio rat performer <
#    ff  score:  1
#    xgb score:  1
# random index: 1556
# > strings second choice elixir 8020 bronze warmer sounding well balanced cost lot well worth <
#    ff  score:  1
#    xgb score:  1
# random index: 445
# > pedal working making noise poor quality controlactually looks like used pedal like newdont recommend product <
#    ff  score:  1
#    xgb score:  1
# random index: 1220
# > good tunner bypass switch think good choise pedalboards changed tc electronic polytune <
#    ff  score:  1
#    xgb score:  1

# %%
print(bold('Accuracy')+'\n--------')
print('   XGB : ', np.round(xgb_accuracy*100, 2), '%')
print('   FF  : ', np.round(ff_accuracy*100, 2),'%')
print(bold('Train time')+'\n----------')
print('   XGB : {:.2f}'.format( xgb_train_time,2 ) + ' seg.')
print('   FF  : {:.2f}'.format( np.round(ff_train_time, 2)) + ' seg.')
print('y_pred difference : ', y_pred_xgb==y_pred_ffi)
# Out:
# Accuracy
# --------
#    XGB :  88.07 %
#    FF  :  83.87 %
# Train time
# ----------
#    XGB : 46.00 seg.
#    FF  : 54.93 seg.
# y_pred difference :  [ True  True  True ...  True  True  True]

# %% [markdown]
# # 5 - Modelo GRU

# %% [markdown]
# ## Dependencias

# %%
import multiprocessing
from gensim.models import Word2Vec
try:
  from gensim.models import Word2Vec
except:
  # !pip install gensim

# %%
cores = multiprocessing.cpu_count() # Contamos el número de cores en el ordenador
print ('Available cores:', cores)
# Out:
# Available cores: 2

# %% [markdown]
# ## Embedding
#
# En esta parte creamos el embedding que nos da la relación semántica entre las palabras del corpus.

# %%
# We're creating embeddings for GRU model
w2v_model = Word2Vec(min_count=20,
                     window=2,
                     vector_size=300,
                     sample=6e-5,
                     alpha=0.03,
                     min_alpha=0.0007,
                     negative=20,
                     workers=cores-1)

# %%
t_start = time.time()
sent = [row.split() for row in x_train]
w2v_model.build_vocab(sent, progress_per=10000)
t_end = time.time()

# %%
print('Time to build the vocabulary: {} mins'.format(round((t_end - t_start) / 60, 2)))
print('The vocabulary is composed by {} words'.format(len(w2v_model.wv.key_to_index)))
# Out:
# Time to build the vocabulary: 0.0 mins
# The vocabulary is composed by 1277 words

# %%
# Training word2vec model
t_start = time.time()

w2v_model.train(sent, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

t_end = time.time()

# %%
print('Time to train the model: {} mins'.format(round((t_end - t_start) / 60, 2)))
# Out:
# Time to train the model: 0.17 mins

# %% [markdown]
# ### Información del word2vec generado

# %%
w2v_model.wv.most_similar(positive=["guitar"])
# Out:
# [('guitars', 0.987044632434845),
#  ('neck', 0.9796016216278076),
#  ('locks', 0.975145161151886),
#  ('straps', 0.9686566591262817),
#  ('lock', 0.9598761200904846),
#  ('uke', 0.9590210318565369),
#  ('nylon', 0.9588447213172913),
#  ('locking', 0.9586886167526245),
#  ('hold', 0.956464409828186),
#  ('acoustic', 0.956436038017273)]

# %%
w2v_model.wv.most_similar(positive=["string"])
# Out:
# [('acoustic', 0.9754698276519775),
#  ('elixir', 0.9698543548583984),
#  ('wound', 0.9670790433883667),
#  ('bronze', 0.9635582566261292),
#  ('coated', 0.9631199836730957),
#  ('martin', 0.962031364440918),
#  ('daddario', 0.9616798162460327),
#  ('steel', 0.9593961834907532),
#  ('last', 0.9581807255744934),
#  ('longer', 0.958154559135437)]

# %%
w2v_model.wv.most_similar(positive=["drum"])
# Out:
# [('portable', 0.9954089522361755),
#  ('drums', 0.9950161576271057),
#  ('equipment', 0.993976891040802),
#  ('stage', 0.9937447905540466),
#  ('function', 0.9934114813804626),
#  ('need', 0.9933651685714722),
#  ('able', 0.9931591153144836),
#  ('desktop', 0.9928667545318604),
#  ('mike', 0.9924976229667664),
#  ('device', 0.9920425415039062)]

# %%
w2v_model.wv.similarity('guitar', 'string')
# Out:
# np.float32(0.90897965)

# %%
w2v_model.wv.similarity('microphone', 'banjo')
# Out:
# np.float32(0.7942375)

# %%
w2v_model.wv.doesnt_match(['strings', 'guitar', 'device'])
# Out:
# 'strings'

# %%
w2v_model.wv.vectors
# Out:
# array([[-0.09268105,  0.09548959,  0.01112183, ..., -0.11176256,
#          0.02646852,  0.17833765],
#        [-0.18476938,  0.07363865, -0.06206161, ..., -0.09474501,
#          0.04715651,  0.13696492],
#        [-0.09311258,  0.08871922, -0.04850857, ..., -0.06629765,
#          0.05099511,  0.0928389 ],
#        ...,
#        [-0.17680179,  0.07628514, -0.06107659, ..., -0.07584647,
#          0.05030879,  0.10233977],
#        [-0.17191096,  0.08786197, -0.05125877, ..., -0.08637946,
#          0.04450213,  0.1323358 ],
#        [-0.1527446 ,  0.07076406, -0.05378653, ..., -0.08316445,
#          0.02411805,  0.13048066]], dtype=float32)

# %% [markdown]
# ## Tokenizing & Padding train data

# %% [markdown]
# La tokenización se encarga de pasar cada palabra a número para que pueda ser tratada por el modelo.
#
# El padding se ocupa de dejar todos los registros de la misma longitud para que el modelo lo trate de forma eficiente.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_words = int(median_words_rw)  # sequence length


# Initialize tokenizer
tokenizr = Tokenizer(oov_token="<OOV>")
tokenizr.fit_on_texts(x_train)

vocab_size =  len(tokenizr.word_index) + 1  # vocabulary size

# texte to sequence
seq = tokenizr.texts_to_sequences(x_train)
x_train_gru = pad_sequences(seq, padding='post', truncating='post', maxlen=max_words)

seq_test = tokenizr.texts_to_sequences(x_test)
x_test_gru = pad_sequences(seq_test, padding='post', truncating='post', maxlen=max_words)

# %%
print(bold('Raw             :'), x_train[100:])
print(bold('Vocabulary size :'), vocab_size)
print(bold('Sequences       :'), seq)
print(bold('Pad sequences   :'), x_train_gru)
print(bold('Word index      :'), tokenizr.word_index)
# Out:
# Raw             : ['elixir strings nice slick last forever compared standard stringsbut admit addario strings good replaced often money want try technology advanced strings dont think disappointed people say slick'
#  'harmonica barely fits holder adjustment distance mouth harmonica cant get harmonica adjusted close enough play unless modify'
#  'unfortunately wasnt aware slides come sizes got medium need large medium fits pinky finger thats okay prefered fit index finger id controli cannot fault slide foolish choice'
#  ...
#  'simple humidifier guitars round sound hole would work fhole archtop types instruments mandolin ukulele inside sturdy plastic case appears ordinary kitchen sponge use distilled water recommended last'
#  'les paul heavy strap would constantly fall decided get set strap locks installed minutes really dont change look guitar need nut driver screw lock strap dont locks'
#  'guitar stand built good buy cost would purchase']
# Vocabulary size : 15198
# Sequences       : [[5, 23, 118, 34, 553, 8, 12, 292, 37, 9, 475, 6537, 946, 3341, 825, 466, 8], [781, 40, 19, 235, 289, 5, 10, 5, 682, 63, 1324, 289, 5, 1958, 10, 6538, 312, 6539, 322, 404, 359, 6540, 2, 671, 190, 148, 22], [1822, 52, 4756, 3342, 4757, 4758, 6541, 871, 1178, 52, 225, 3850, 6542, 8, 795, 1220, 69, 796, 974, 8, 3851, 6543, 1959, 52, 3851, 1960, 3851], [170, 43, 16, 21, 4, 23, 899, 572, 1547, 1375, 190, 416, 6544, 247, 632, 72, 228, 2951, 723, 220, 247, 446, 3852, 1000, 2234, 446, 1279], [1376, 44, 305, 259, 593, 82, 1720, 428, 63, 70, 68, 1961, 6545, 2, 6546, 6547, 71, 9, 672, 221, 4759, 1721, 247, 2, 975, 268, 750], [1823, 199, 33, 541, 2235, 704, 4, 35, 6548, 173, 232, 170, 19, 112, 1483, 417, 705, 348, 2082, 216, 323, 100, 10, 2, 1280, 498, 2952], [1221, 353, 440, 164, 7, 40, 101, 9, 3853, 309, 422, 782, 499, 88, 82, 764, 164, 133, 653, 31, 349, 20, 2083, 40, 74, 63, 31], [110, 582, 3, 171, 7, 1962, 1824, 56, 5, 683, 202, 21, 306, 1484, 29, 1140, 160, 68, 418, 270, 101, 271, 483, 20, 1001, 815, 4760], [396, 298, 8, 2, 51, 391, 85, 3343, 3344, 1075, 342, 608, 3345, 72, 405, 329, 1141, 6549, 109, 1634, 3854, 8, 252, 186, 323, 22, 10], [79, 277, 2, 14, 429, 3855, 2236, 324, 10, 169, 542, 1024, 50, 243, 52, 52, 20, 60, 50, 900, 52, 2, 44, 2641, 52, 215, 6550], [18, 21, 143, 554, 27, 1222, 947, 4761, 97, 1377, 248, 251, 1076, 663, 6551, 268, 24, 948, 3856, 73, 664, 554, 4, 81, 4762, 126, 4763], [712, 684, 64, 621, 3857, 77, 1077, 78, 1435, 298, 4, 7, 333, 901, 2953, 6552, 49, 765, 1142, 1325, 65, 149, 49, 47, 4764, 1325, 491], [98, 69, 594, 573, 2954, 6553, 145, 925, 6554, 1114, 1078, 797, 11, 3], [433, 226, 27, 79, 127, 13, 71, 27, 6, 91, 33, 4765, 226, 64, 103, 95, 118, 2084, 2642, 458, 157, 1722], [139, 1143, 149, 6555, 1077, 6, 95, 1723, 2955, 2643, 2955, 4766, 1045, 1723, 2955, 52, 4767, 215, 4767, 4768, 492, 10, 238, 4769, 1723, 1724, 2427], [161, 135, 1825, 45, 91, 33, 516, 1046, 29], [4770, 37, 96, 111, 3, 84, 685, 6556], [349, 1144, 16, 35, 126, 15, 3858, 223, 1145, 6557, 84, 4, 244, 360, 11, 3], [13, 7, 6558, 350, 4771, 4772, 268, 6559, 350, 268, 318, 70, 14, 2956, 493, 27, 419, 350, 6560, 3859, 35, 96, 6561], [216, 166, 348, 23, 1378, 61, 98, 686, 76, 609, 191, 19, 76, 28, 13, 2428, 113, 434, 949, 555, 6562, 417, 6563, 248, 976, 6564, 19], [51, 2, 441, 36, 16, 325, 279, 565, 33, 1223, 1179, 18, 2, 950, 632, 2237, 349, 26, 38, 2, 117, 9, 155, 2, 385, 798, 2085], [21, 4, 2238, 330, 724, 26, 14, 58, 484, 4, 556, 122, 1281, 2086, 63, 376, 3, 70, 2957, 122, 61, 6565, 157, 42], [140, 207, 4773, 713, 1725, 2239, 11, 3, 28, 127, 296, 359, 263, 1485, 205], [243, 493, 55, 533, 1726, 1224, 783, 206, 371, 1047, 9, 1963, 1826, 737, 6566, 85, 30, 1282, 1826, 120, 500, 665, 371, 654, 243, 6567, 1548], [273, 56, 1283, 2, 208, 572, 2, 235, 23, 633, 1827, 1025, 1379, 6568, 926, 1379, 54, 392, 1379, 364, 2958, 2, 1048, 72, 3860], [253, 3861, 31, 845, 6569, 434, 229, 2087, 1142, 1225, 1380, 2429, 1548, 3862, 2088, 49, 109, 826, 2240, 517, 41, 348, 62, 751, 202, 1436, 1727], [3346, 155, 1180, 109, 126, 816, 3863, 1828, 289, 334, 129, 37, 98, 799, 96, 766, 5, 72, 5, 10, 19, 1829], [7, 534, 107, 4, 126, 451, 232, 272, 4774, 104, 19, 149, 4775, 10, 6570, 512, 133, 280, 6571, 217, 8, 1635, 423, 4, 500, 6572, 72], [9, 44, 11, 7, 1549, 645, 7, 44, 19, 406, 44, 64, 583, 146], [126, 24, 2430, 4776, 977, 738, 34, 111, 926, 140, 249, 197, 222, 501, 1326, 151, 1830], [67, 117, 29, 1634, 2644, 2241, 2, 595, 69, 485, 392, 197, 2, 326, 2089, 5, 233, 5, 1181, 377, 846, 752, 2, 1381, 2959, 233, 2241], [253, 21, 4777, 6573, 451, 902, 634, 3347, 253, 6574, 2090, 1115, 6575, 105, 512, 6576, 903, 6577, 397, 8, 2645, 6578, 6579, 45, 91, 6580, 3864], [127, 3348, 2, 14, 549, 2646, 899, 20, 6, 299, 817, 15, 1728, 596, 2431], [6581, 65, 241, 2, 3, 10, 24, 2242, 42, 4, 6582, 18, 310, 4, 593, 6583, 37, 83, 800, 1723, 230, 1964, 435, 72, 69, 187, 53], [22, 4, 58, 318, 64, 40, 226, 3865, 199, 251, 57, 153, 64, 33], [95, 476, 259, 335, 27, 976, 126, 27, ...
# Pad sequences   : [[   5   23  118 ...  825  466    8]
#  [ 781   40   19 ...   10 6538  312]
#  [1822   52 4756 ...  795 1220   69]
#  ...
#  [ 144 2339   33 ...  423  135  146]
#  [ 358  375  133 ...   13   23  193]
#  [   2   29  155 ...    0    0    0]]
# Word index      : {'<OOV>': 1, 'guitar': 2, 'great': 3, 'one': 4, 'good': 5, 'use': 6, 'like': 7, 'strings': 8, 'well': 9, 'sound': 10, 'works': 11, 'price': 12, 'really': 13, 'get': 14, 'little': 15, 'ive': 16, 'pedal': 17, 'bought': 18, 'quality': 19, 'would': 20, 'used': 21, 'nice': 22, 'dont': 23, 'easy': 24, 'picks': 25, 'much': 26, 'strap': 27, 'im': 28, 'stand': 29, 'amp': 30, 'time': 31, 'using': 32, 'guitars': 33, 'better': 34, 'got': 35, 'years': 36, 'work': 37, 'love': 38, 'play': 39, 'cable': 40, 'mic': 41, 'buy': 42, 'product': 43, 'made': 44, 'acoustic': 45, 'need': 46, 'also': 47, 'first': 48, 'tone': 49, 'tuner': 50, 'playing': 51, 'string': 52, 'pick': 53, 'best': 54, 'fender': 55, 'thing': 56, 'say': 57, 'small': 58, 'right': 59, 'put': 60, 'pedals': 61, 'bit': 62, 'long': 63, 'cheap': 64, 'want': 65, 'sounds': 66, 'perfect': 67, 'even': 68, 'way': 69, 'enough': 70, 'bass': 71, 'go': 72, 'two': 73, 'last': 74, 'recommend': 75, 'cables': 76, 'cant': 77, 'make': 78, 'pretty': 79, 'feel': 80, 'set': 81, 'lot': 82, 'case': 83, 'new': 84, 'back': 85, 'many': 86, 'job': 87, 'around': 88, 'without': 89, 'still': 90, 'electric': 91, 'could': 92, 'always': 93, 'tune': 94, 'looking': 95, 'fine': 96, 'far': 97, 'needed': 98, 'doesnt': 99, 'different': 100, 'hold': 101, 'fit': 102, 'keep': 103, 'tried': 104, 'light': 105, 'never': 106, 'try': 107, 'think': 108, 'makes': 109, 'purchased': 110, 'looks': 111, 'capo': 112, 'know': 113, 'look': 114, 'didnt': 115, 'seems': 116, 'solid': 117, 'see': 118, 'music': 119, 'find': 120, 'money': 121, 'power': 122, 'tuners': 123, 'high': 124, 'size': 125, 'another': 126, 'sure': 127, 'since': 128, 'hard': 129, 'found': 130, 'easily': 131, 'give': 132, 'heavy': 133, 'something': 134, 'sturdy': 135, 'old': 136, '2': 137, 'instrument': 138, 'wanted': 139, 'tuning': 140, 'neck': 141, 'though': 142, 'every': 143, 'simple': 144, 'microphone': 145, 'plastic': 146, 'came': 147, 'quite': 148, 'low': 149, 'fits': 150, 'metal': 151, 'going': 152, 'take': 153, 'ones': 154, 'built': 155, 'problem': 156, 'worth': 157, 'however': 158, 'thats': 159, 'come': 160, 'several': 161, 'big': 162, 'noise': 163, 'seem': 164, 'expensive': 165, 'perfectly': 166, 'ordered': 167, 'ever': 168, 'board': 169, 'excellent': 170, 'reviews': 171, 'end': 172, 'happy': 173, 'bag': 174, 'thought': 175, '3': 176, 'couple': 177, 'amazon': 178, 'youre': 179, 'clean': 180, 'effects': 181, 'exactly': 182, 'dunlop': 183, 'studio': 184, 'box': 185, 'durable': 186, 'home': 187, 'highly': 188, 'boss': 189, 'actually': 190, 'comes': 191, 'behringer': 192, 'change': 193, 'recording': 194, '5': 195, 'purchase': 196, 'holds': 197, 'id': 198, 'nothing': 199, 'things': 200, 'less': 201, 'almost': 202, 'problems': 203, 'distortion': 204, 'yet': 205, 'tube': 206, 'accurate': 207, 'stands': 208, 'theyre': 209, 'item': 210, 'probably': 211, 'three': 212, 'wont': 213, 'might': 214, 'volume': 215, 'worked': 216, '6': 217, 'amazing': 218, 'may': 219, 'standard': 220, 'extra': 221, 'longer': 222, 'snark': 223, 'awesome': 224, 'read': 225, 'comfortable': 226, 'top': 227, 'wrong': 228, 'definitely': 229, 'practice': 230, 'decided': 231, 'said': 232, 'bad': 233, 'strat': 234, 'place': 235, 'brand': 236, 'gig': 237, 'cost': 238, 'plug': 239, 'others': 240, 'inexpensive': 241, '4': 242, 'switch': 243, 'bright': 244, 'fast': 245, 'getting': 246, '10': 247, 'anything': 248, 'easier': 249, 'unit': 250, 'else': 251, 'strong': 252, 'review': 253, 'ukulele': 254, 'people': 255, 'side': 256, 'everything': 257, 'super': 258, 'leather': 259, 'ago': 260, 'times': 261, 'stage': 262, 'havent': 263, 'planet': 264, 'daddario': 265, 'year': 266, 'player': 267, 'straps': 268, 'either': 269, 'able': 270, 'weight': 271, 'ok': 272, 'clip': 273, 'waves': 274, 'expected': 275, 'stuff': 276, 'decent': 277, 'design': 278, 'played': 279, 'fingers': 280, 'months': 281, 'expect': 282, 'cool': 283, 'mics': 284, 'instruments': 285, 'line': 286, 'deal': 287, 'difference': 288, ' ...

# %%
# Obtenemos la dimensión del Word2Vec
embedding_dim = w2v_model.vector_size  # 300

# creamos matriz vacía
embedding_matrix = np.zeros((vocab_size, embedding_dim))

# Llenamos la matriz
for word, i in tokenizr.word_index.items():
    if word in w2v_model.wv:
        embedding_matrix[i] = w2v_model.wv[word]

# %% [markdown]
# ## Entrenar el modelo

# %%
from keras.models import Sequential
from keras.layers import Embedding,  Dense, Dropout, GRU

embedding_size = 32
gru_model = Sequential()
gru_model.add(Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], input_length=max_words))
gru_model.add(GRU(64))
gru_model.add(Dense(1, activation='sigmoid'))

print(gru_model.summary())
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)        │ ?                      │     4,559,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_6 (GRU)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,559,400 (17.39 MB)
#  Trainable params: 4,559,400 (17.39 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
gru_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Split de las secuencias rellenadas
X_train_final, X_valid, y_train_final, y_valid = train_test_split(
    x_train_gru, y_train, test_size=0.2, random_state=42
)

# %%
batch_size = 64
num_epochs = 1

gru_model.fit(X_train_final, y_train_final,
              validation_data=(X_valid, y_valid),
              batch_size=batch_size,
              epochs=num_epochs)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.8731 - loss: 0.3836 - val_accuracy: 0.8700 - val_loss: 0.3851

# %%
import os

# %%
# guardamos el modelo en el colab
cache_dir='./'
model_file = "gru_model.h5"  # HDF5 file
gru_model.save(os.path.join(cache_dir, model_file))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Obtenemos accuracy
scores = gru_model.evaluate(X_valid, y_valid, verbose=0)  # returns loss and other metrics specified in model.compile()
gru_accuracy = scores[1]*100
print("Test accuracy: {:>6.2f}%".format(gru_accuracy, 2))  # scores[1] should correspond to accuracy if you passed in metrics=['accuracy']
# Out:
# Test accuracy:  87.00%

# %% [markdown]
# ## Métricas y conclusiones (GRU)

# %%
gru_pred = gru_model.predict(X_valid)
# Out:
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
def metricas_gru():
  # Initializing array of integers
  y_pred_gru = np.empty_like(gru_pred)

  for i in range(len(y_pred_gru)):
    if y_pred_gru[i][0] == np.nan:
      y_pred_gru[i][0] = 0
    try:
      y_pred_gru[i] = int(np.round(y_pred_gru[i][0]))
    except:
      y_pred_gru[i] = 0


  # Printing predictions

  length_gru = len(y_pred_gru)
  count_0_gru = 0
  count_1_gru = 0
  for j in range(len(y_pred_gru)):
    if y_pred_gru[j] == 0:
      count_0_gru += 1
    else:
      count_1_gru += 1

def mostrar_metricas_gru():
  metricas_gru()
  print(bold('Prediction gru'))
  print('  gru accuracy: {:>4.2f}'.format(gru_accuracy))
  print('  0 gru : {:>4}'.format(count_0_gru), '({:>6.2f}%)'.format(count_0_gru/length_gru * 100))
  print('  1 gru : {:>4}'.format(count_1_gru), '({:>6.2f}%)'.format(count_1_gru/length_gru * 100))
  print('\n')

# %%
mostrar_metricas_gru()
mostrar_metricas_ff()
mostrar_metricas_xgb()
# Out:
# Prediction gru
#   gru accuracy: 87.00
#   0 gru :  271 ( 17.61%)
#   1 gru : 1268 ( 82.39%)
#
#
# Prediction ffi
#   ff accuracy: 83.87
#   0 ff :  342 ( 13.33%)
#   1 ff : 2224 ( 86.67%)
#
#
# Prediction xgb
#  xgb accuracy: 88.07
#         0 xgb:   42 (  1.64%)
#         1 xgb: 2524 ( 98.36%)
